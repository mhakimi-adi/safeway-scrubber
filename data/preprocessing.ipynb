# %%
import pandas

# %%
df = pandas.read_json("data.json")
df
# Out:
#                                                     name        pid  \
# 0      Enfamil Nutramigen Infant Formula Milk Powder ...  960026132
# 1      Enfamil Gentlease Infant Formula Milk Based Po...  960455518
# 2      Enfagrow Premium Milk Toddler Next Step Nutrit...  960518581
# 3      Enfagrow Toddler Next Step Vanilla Powder - 32 OZ  970012939
# 4      Huggies Natural Care Unscented Sensitive Baby ...  960500714
# ...                                                  ...        ...
# 34112          Pike Rotator Series 6pk In Cans - 6-12 FZ  970075245
# 34113           Waterbrook Washington Rose Wine - 375 Ml  960530557
# 34114  101 North Pinot Grigio California Wine In Bott...  970097652
# 34115  101 North Wine to Go Chardonnay California Win...  970122979
# 34116                 Wine Single 6-10 Fz Bottles - 6 FZ  970020974
#
#                upc         id  featured  inventoryAvailable  pastPurchased  \
# ...
